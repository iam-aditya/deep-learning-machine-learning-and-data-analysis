# %%
import pandas as pd

df = pd.read_excel('https://ibm.box.com/shared/static/lw190pt9zpy5bd1ptyg2aw15awomz9pu.xlsx',
                       sheet_name='Canada by Citizenship',
                       skiprows=range(20),
                       skipfooter=2
                      )

# %%
print(df.dtypes)
print(df.shape)
df.head(5)
# Out:
# Type        object
# Coverage    object
# OdName      object
# AREA         int64
# AreaName    object
# REG          int64
# RegName     object
# DEV          int64
# DevName     object
# 1980         int64
# 1981         int64
# 1982         int64
# 1983         int64
# 1984         int64
# 1985         int64
# 1986         int64
# 1987         int64
# 1988         int64
# 1989         int64
# 1990         int64
# 1991         int64
# 1992         int64
# 1993         int64
# 1994         int64
# 1995         int64
# 1996         int64
# 1997         int64
# 1998         int64
# 1999         int64
# 2000         int64
# 2001         int64
# 2002         int64
# 2003         int64
# 2004         int64
# 2005         int64
# 2006         int64
# 2007         int64
# 2008         int64
# 2009         int64
# 2010         int64
# 2011         int64
# 2012         int64
# 2013         int64
# dtype: object
# (195, 43)
#          Type    Coverage          OdName  AREA AreaName   REG  \
# ...

# %%
def con(exp):
    if type(exp) ==int:
        return str(exp)
    else:
        return exp
df.columns=list(map(con,df.columns))    
df.columns=df.columns.astype(str)

# %%
df['total']=df.sum(axis=1)

# %%
df.drop(['Type','Coverage','REG','DEV','AREA'],axis=1,inplace=True)

# %%
print(df.head(3))
# Out:
#         OdName AreaName          RegName             DevName  1980  1981  \
# 0  Afghanistan     Asia    Southern Asia  Developing regions    16    39
# 1      Albania   Europe  Southern Europe   Developed regions     1     0
# 2      Algeria   Africa  Northern Africa  Developing regions    80    67
#
#    1982  1983  1984  1985  ...    2005  2006  2007  2008  2009  2010  2011  \
# 0    39    47    71   340  ...    3436  3009  2652  2111  1746  1758  2203
# 1     0     0     0     0  ...    1223   856   702   560   716   561   539
# 2    71    69    63    44  ...    3626  4807  3623  4005  5393  4752  4325
#
#    2012  2013  total
# 0  2635  2004  65977
# 1   620   603  18433
# 2  3774  4331  72156
#
# [3 rows x 39 columns]

# %%
df.rename(columns={'OdName':'country','AreaName':'continent','RegName':'region','DevName':'dev'},inplace=True)

# %%
df.head(3)
# Out:
#        country continent           region                 dev  1980  1981  \
# 0  Afghanistan      Asia    Southern Asia  Developing regions    16    39
# 1      Albania    Europe  Southern Europe   Developed regions     1     0
# 2      Algeria    Africa  Northern Africa  Developing regions    80    67
#
#    1982  1983  1984  1985  ...    2005  2006  2007  2008  2009  2010  2011  \
# 0    39    47    71   340  ...    3436  3009  2652  2111  1746  1758  2203
# 1     0     0     0     0  ...    1223   856   702   560   716   561   539
# 2    71    69    63    44  ...    3626  4807  3623  4005  5393  4752  4325
#
#    2012  2013  total
# 0  2635  2004  65977
# 1   620   603  18433
# 2  3774  4331  72156
#
# [3 rows x 39 columns]

# %%
df.describe(include='all')
# Out:
#        country continent        region                 dev          1980  \
# count      195       195           195                 195    195.000000
# unique     195         6            22                   2           NaN
# top     Monaco    Africa  Western Asia  Developing regions           NaN
# freq         1        54            18                 147           NaN
# mean       NaN       NaN           NaN                 NaN    508.394872
# std        NaN       NaN           NaN                 NaN   1949.588546
# min        NaN       NaN           NaN                 NaN      0.000000
# 25%        NaN       NaN           NaN                 NaN      0.000000
# 50%        NaN       NaN           NaN                 NaN     13.000000
# 75%        NaN       NaN           NaN                 NaN    251.500000
# max        NaN       NaN           NaN                 NaN  22045.000000
#
#                 1981          1982          1983          1984         1985  \
# ...

# %%
dc=df.set_index('country')
dc.sort_values(['total'],ascending=False,axis=0,inplace=True)

# %%
dc.loc['India']
# Out:
# continent                  Asia
# region            Southern Asia
# dev          Developing regions
# 1980                       8880
# 1981                       8670
# 1982                       8147
# 1983                       7338
# 1984                       5704
# 1985                       4211
# 1986                       7150
# 1987                      10189
# 1988                      11522
# 1989                      10343
# 1990                      12041
# 1991                      13734
# 1992                      13673
# 1993                      21496
# 1994                      18620
# 1995                      18489
# 1996                      23859
# 1997                      22268
# 1998                      17241
# 1999                      18974
# 2000                      28572
# 2001                      31223
# 2002                      31889
# 2003                      27155
# 2004                      28235
# 2005                      36210
# ...

# %%
dc.transpose()
# Out:
# country                 India               China  \
# continent                Asia                Asia
# region          Southern Asia        Eastern Asia
# dev        Developing regions  Developing regions
# 1980                     8880                5123
# 1981                     8670                6682
# 1982                     8147                3308
# 1983                     7338                1863
# 1984                     5704                1527
# 1985                     4211                1816
# 1986                     7150                1960
# 1987                    10189                2643
# 1988                    11522                2758
# 1989                    10343                4323
# 1990                    12041                8076
# 1991                    13734               14255
# 1992                    13673               10846
# 1993                    21496                9817
# 1994                    18620               13128
# ...

# %%
years=list(map(str,range(1980,2014)))
dv=dc[years]
dv
# Out:
#                                                      1980   1981   1982  \
# country
# India                                                8880   8670   8147
# China                                                5123   6682   3308
# United Kingdom of Great Britain and Northern Ir...  22045  24796  20620
# Philippines                                          6051   5921   5249
# Pakistan                                              978    972   1201
# United States of America                             9378  10030   9074
# Iran (Islamic Republic of)                           1172   1429   1822
# Sri Lanka                                             185    371    290
# Republic of Korea                                    1011   1456   1572
# Poland                                                863   2930   5881
# Lebanon                                              1409   1119   1159
# France                                               1729   2027   2219
# ...

# %%
dt=dv[years].transpose()
dt.loc['tot']=dt.sum(axis=0)
dt
# Out:
# country   India   China  United Kingdom of Great Britain and Northern Ireland  \
# 1980       8880    5123                                              22045
# 1981       8670    6682                                              24796
# 1982       8147    3308                                              20620
# 1983       7338    1863                                              10015
# 1984       5704    1527                                              10170
# 1985       4211    1816                                               9564
# 1986       7150    1960                                               9470
# 1987      10189    2643                                              21337
# 1988      11522    2758                                              27359
# 1989      10343    4323                                              23795
# 1990      12041    8076                                              31668
# ...

# %%
decr=dt.sort_values(['tot'],axis=1,ascending=False,)

# %% [raw]
# print(decr)

# %%
decr=decr.transpose()
decr
# Out:
#                                                      1980   1981   1982  \
# country
# India                                                8880   8670   8147
# China                                                5123   6682   3308
# United Kingdom of Great Britain and Northern Ir...  22045  24796  20620
# Philippines                                          6051   5921   5249
# Pakistan                                              978    972   1201
# United States of America                             9378  10030   9074
# Iran (Islamic Republic of)                           1172   1429   1822
# Sri Lanka                                             185    371    290
# Republic of Korea                                    1011   1456   1572
# Poland                                                863   2930   5881
# Lebanon                                              1409   1119   1159
# France                                               1729   2027   2219
# ...

# %%
decr=decr.head(5)
decr
# Out:
#                                                      1980   1981   1982  \
# country
# India                                                8880   8670   8147
# China                                                5123   6682   3308
# United Kingdom of Great Britain and Northern Ir...  22045  24796  20620
# Philippines                                          6051   5921   5249
# Pakistan                                              978    972   1201
#
#                                                      1983   1984  1985  1986  \
# country
# India                                                7338   5704  4211  7150
# China                                                1863   1527  1816  1960
# United Kingdom of Great Britain and Northern Ir...  10015  10170  9564  9470
# Philippines                                          4562   3801  3150  4166
# Pakistan                                              900    668   514   691
#
# ...

# %%
decr.transpose()
# Out:
# country   India   China  United Kingdom of Great Britain and Northern Ireland  \
# 1980       8880    5123                                              22045
# 1981       8670    6682                                              24796
# 1982       8147    3308                                              20620
# 1983       7338    1863                                              10015
# 1984       5704    1527                                              10170
# 1985       4211    1816                                               9564
# 1986       7150    1960                                               9470
# 1987      10189    2643                                              21337
# 1988      11522    2758                                              27359
# 1989      10343    4323                                              23795
# 1990      12041    8076                                              31668
# ...

# %%
decr=decr.drop(['tot'],axis=1)

# %%
decr.columns=decr.columns.map(int)

# %%
decr=decr.transpose()

# %%
decr.plot(kind='area')
print(decr)
# Out:
# country  India  China  United Kingdom of Great Britain and Northern Ireland  \
# 1980      8880   5123                                              22045
# 1981      8670   6682                                              24796
# 1982      8147   3308                                              20620
# 1983      7338   1863                                              10015
# 1984      5704   1527                                              10170
# 1985      4211   1816                                               9564
# 1986      7150   1960                                               9470
# 1987     10189   2643                                              21337
# 1988     11522   2758                                              27359
# 1989     10343   4323                                              23795
# 1990     12041   8076                                              31668
# 1991     13734  14255                                              23380
# ...

# %%
dt.head()
# Out:
# country  India  China  United Kingdom of Great Britain and Northern Ireland  \
# 1980      8880   5123                                              22045
# 1981      8670   6682                                              24796
# 1982      8147   3308                                              20620
# 1983      7338   1863                                              10015
# 1984      5704   1527                                              10170
#
# country  Philippines  Pakistan  United States of America  \
# 1980            6051       978                      9378
# 1981            5921       972                     10030
# 1982            5249      1201                      9074
# 1983            4562       900                      7100
# 1984            3801       668                      6661
#
# country  Iran (Islamic Republic of)  Sri Lanka  Republic of Korea  Poland  \
# 1980                           1172        185               1011     863
# ...

# %%
incr=dt.transpose()

# %%
incr=incr.sort_values(['tot'],ascending=True,axis=0)

# %%
incr=incr.drop(['tot'],axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-93-81764ac9980d> in <module>
# ----> 1 incr=incr.drop(['tot'],axis=1)
#       2 incr=incr.head(5)
#
# ~/.local/lib/python3.5/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3695                                            index=index, columns=columns,
#    3696                                            level=level, inplace=inplace,
# -> 3697                                            errors=errors)
#    3698
#    3699     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ~/.local/lib/python3.5/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3109         for axis, labels in axes.items():
#    3110             if labels is not None:
# ...

# %%
incr=incr.head(5)

# %%
incr.columns=incr.columns.map(int)

# %%
incr=incr.transpose()

# %%
incr.plot(kind='area',alpha=0.5,stacked='False')

# %%
dt.sort_values(['tot'],ascending=True,axis=1)
# Out:
# country  Palau  Western Sahara  Marshall Islands  San Marino  New Caledonia  \
# 1980         0               0                 0           1              0
# 1981         0               0                 0           0              0
# 1982         0               0                 0           0              0
# 1983         0               0                 0           0              0
# 1984         0               0                 0           0              0
# 1985         0               0                 0           0              0
# 1986         0               0                 0           1              0
# 1987         0               0                 0           0              0
# 1988         0               0                 0           0              0
# 1989         0               0                 0           0              0
# 1990         0               0                 0           1              0
# ...

# %%
dtr=dv['2013']

# %%
import numpy as np
count ,bin_edges=np.histogram(dtr)

# %%
print('bin_edges are',bin_edges)
print('frequency',count)
# Out:
# bin_edges are [    0.   3412.9  6825.8 10238.7 13651.6 17064.5 20477.4 23890.3 27303.2
#  30716.1 34129. ]
# frequency [178  11   1   2   0   0   0   0   1   2]

# %%
dtr.plot(kind='hist',xticks=bin_edges)

# %%
dice=dv.loc['Iceland']
dice.plot(kind='bar',figsize=(20,10))
plt.annotate('',                      # s: str. Will leave it blank for no text
             xy=(32, 70),             # place head of the arrow at point (year 2012 , pop 70)
             xytext=(28, 20),         # place base of the arrow at point (year 2008 , pop 20)
             xycoords='data',         # will use the coordinate system of the object being annotated 
             arrowprops=dict(arrowstyle='->', connectionstyle='arc3', color='blue', lw=2)
            )
plt.annotate('2008 - 2011 Financial Crisis', # text to display
             xy=(28, 30),                    # start the text at at point (year 2008 , pop 30)
             rotation=72.5,                  # based on trial and error to match the arrow
             va='bottom',                    # want the text to be vertically 'bottom' aligned
             ha='left',                      # want the text to be horizontally 'left' algned.
            )
# Out:
# Text(28, 30, '2008 - 2011 Financial Crisis')

# %%
df.columns=df.columns.map(str)

# %%
dcont=df.groupby(['continent']).sum()

# %%
dcont
# Out:
#                                   1980   1981   1982   1983   1984   1985  \
# continent
# Africa                            3951   4363   3819   2671   2639   2650
# Asia                             31025  34314  30214  24696  27274  23850
# Europe                           39760  44802  42720  24638  22287  20844
# Latin America and the Caribbean  13081  15215  16769  15427  13678  15171
# Northern America                  9378  10030   9074   7100   6661   6543
# Oceania                           1942   1839   1675   1018    878    920
#
#                                   1986   1987   1988   1989   ...       2005  \
# continent                                                     ...
# Africa                            3782   7494   7552   9894   ...      27523
# Asia                             28739  43203  47454  60256   ...     159253
# Europe                           24370  46698  54726  60893   ...      35955
# ...

# %%
dcont['total'].plot(kind='pie',autopct='%1.1f%%')

# %%
djap=df[df['country']=='Japan']
djap.set_index(['country'],inplace=True)

# %%
djap.drop(['continent','region','dev','total'],axis=1,inplace=True)

# %%
djap.transpose()
# Out:
# country  Japan
# 1980       701
# 1981       756
# 1982       598
# 1983       309
# 1984       246
# 1985       198
# 1986       248
# 1987       422
# 1988       324
# 1989       494
# 1990       379
# 1991       506
# 1992       605
# 1993       907
# 1994       956
# 1995       826
# 1996       994
# 1997       924
# 1998       897
# 1999      1083
# 2000      1010
# 2001      1092
# 2002       806
# 2003       817
# 2004       973
# 2005      1067
# 2006      1212
# 2007      1250
# 2008      1284
# 2009      1194
# 2010      1168
# 2011      1265
# 2012      1214
# 2013       982

# %%
djap.index=djap.index.map(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-161-7e0765ca1c7e> in <module>
# ----> 1 djap.index=djap.index.map(int)
#
# ~/.local/lib/python3.5/site-packages/pandas/core/indexes/base.py in map(self, mapper, na_action)
#    3447         from .multi import MultiIndex
#    3448         new_values = super(Index, self)._map_values(
# -> 3449             mapper, na_action=na_action)
#    3450
#    3451         attributes = self._get_attributes_dict()
#
# ~/.local/lib/python3.5/site-packages/pandas/core/base.py in _map_values(self, mapper, na_action)
#    1002
#    1003         # mapper is a function
# -> 1004         new_values = map_f(values, mapper)
#    1005
#    1006         return new_values
#
# pandas/_libs/src/inference.pyx in pandas._libs.lib.map_infer()
#
# ValueError: invalid literal for int() with base 10: 'Japan'

# %%
djap=djap.transpose()

# %%
print(djap.head())
djap.plot(kind='line')
djap.plot(kind='box')
# Out:
# country  Japan
# 1980       701
# 1981       756
# 1982       598
# 1983       309
# 1984       246

# %%
djap=djap.transpose()

# %%
djap.plot(kind='bar')

# %%
djap=djap.transpose()

# %%
djap.columns=djap.columns.map(int)

# %%
djap=djap.transpose()

# %%
din=dc.loc['India']
# Out:
# Index(['continent', 'region', 'dev', '1980', '1981', '1982', '1983', '1984',
#        '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993',
#        '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002',
#        '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011',
#        '2012', '2013', 'total'],
#       dtype='object')

# %%
dinf=pd.DataFrame({'years':din.index, 'India':din.values})

# %%
dinf=dinf.set_index(['years'])

# %%
dinf=dinf.transpose()

# %%
dinf.drop(['continent','region','dev','total'],axis=1,inplace=True)

# %%
dinf=dinf.transpose()

# %%
print(dinf)
dinf.columns=dinf.columns.map(int)
# Out:
# years  1980  1981  1982  1983  1984  1985  1986   1987   1988   1989  ...    \
# India  8880  8670  8147  7338  5704  4211  7150  10189  11522  10343  ...
#
# years   2004   2005   2006   2007   2008   2009   2010   2011   2012   2013
# India  28235  36210  33848  28742  28261  29456  34235  27509  30933  33087
#
# [1 rows x 34 columns]

# %%
dinf=dinf.transpose()

# %%
fig=plt.figure()
f1=fig.add_subplot(1,2,1)
f2=fig.add_subplot(1,2,2)
dinf.plot(kind='line',ax=f2)
djap.plot(kind='line',ax=f1)
